# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel(r'C:\Users\Admin\Desktop\Ktm.xlsx')

# %%
df.head()
# Out:
#    Year  Population  Growth Rate
# 0  2025     1673000       0.0314
# 1  2024     1622000       0.0325
# 2  2023     1571000       0.0329
# 3  2022     1521000       0.0333
# 4  2021     1472000       0.0337

# %%
df
# Out:
#     Year  Population  Growth Rate
# 0   2025     1673000       0.0314
# 1   2024     1622000       0.0325
# 2   2023     1571000       0.0329
# 3   2022     1521000       0.0333
# 4   2021     1472000       0.0337
# ..   ...         ...          ...
# 71  1954      108000       0.0093
# 72  1953      107000       0.0094
# 73  1952      106000       0.0095
# 74  1951      105000       0.0096
# 75  1950      104000       0.0000
#
# [76 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))

plt.plot(df['Year'], df['Growth Rate'], linestyle='-')
plt.title('Kathmandu Population Growth Rate')
plt.xlabel('Year')
plt.ylabel('Growth Rate %')
plt.grid(True)

plt.show()

# %%
# bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['Year'], df['Growth Rate'], color='skyblue', edgecolor='black')
plt.title('Population Growth Rate by Year')
plt.xlabel('Year')
plt.ylabel('Growth Rate')

plt.xticks(df['Year'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
colors = plt.cm.viridis((df['Growth Rate'] - df['Growth Rate'].min()) /
                        (df['Growth Rate'].max() - df['Growth Rate'].min()))

# %%
plt.figure(figsize=(10, 4))
bars = plt.bar(df['Year'], df['Growth Rate'], color=colors, edgecolor='black')
